# %% [markdown]
# # EDA Assighnment on the Weather Dataset Analysis

# %% [markdown]
# ## 1. Data Overview and Cleaning

# %%
import pandas as pd
import numpy as np

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ### Characteristics of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df=pd.read_csv(r'C:\Users\LAMECK OMENDA\Downloads\Weather Data.csv')

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# ### There was no null values found therefore the dataset was clean, also there was no duplicate records.

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2. Statistical Summary

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\LAMECK OMENDA\Downloads\Weather Data.csv')
sns.boxplot(data= df)
plt.show()

# %% [markdown]
# Temp_c and Dew Dew Point Temp_C has no outliers and their structure is almost similar.Rel Hum_% has a single extreme outlier which falls
# below the normal values.Wind Speed_km/h has extreme outliers that fall beyond Q3.Visibility_km has several anomalies falling far below Q1
# and Press_kPa has quite evenly distributed anomalies.

# %% [markdown]
# # 3.Data Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## The following histograms show the distribution of key weather parameters - that is Temperature and Humidity

# %%
sns.histplot(df['Temp_C'],kde=True)
plt.title('Temperature Distribution')
plt.show()

# %%
sns.histplot(df['Rel Hum_%'], kde=True)
plt.title("Humidity Distribution")
plt.show()

# %% [markdown]
# ## Plot time series graphs to visualize Dew Point Temp_C and Temp_C over time

# %%
y = df["Dew Point Temp_C"]
x = df["Date/Time"]
plt.scatter(x,y)
plt.title("Scatter Plot of Dew Point Temp_C vs Date/Time")
plt.xlabel("Date/Time")
plt.ylabel("Dew Point Temp_C")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\LAMECK OMENDA\Downloads\Weather Data.csv')

plt.figure(figsize=(10,6))
plt.plot(df['Date/Time'],df['Temp_C'])
plt.title('Temp_C over Time')
plt.xlabel('Date/Time')
plt.ylabel('Temp_C')
plt.show()

# %% [markdown]
# Both Dew Point Temp_C and Temp_C have the same seasonal variation. Their values started increasing then reaching a particular point they
# started decreasing

# %% [markdown]
# ## Correlation matrices and heatmaps identifying different weather parameters.

# %%
df_numeric= df.select_dtypes(include=[float,int])
corr_matrix = df_numeric.corr()
corr_matrix
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind Speed_km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind Speed_km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot = True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # 4. Weather patterns and Trends

# %%
df['Date/Time'] = df['Date/Time']
monthly_avg_temp = df.groupby('Date/Time')['Temp_C'].mean()

plt.plot(monthly_avg_temp)
plt.title('Average Monthly Temperature')
plt.xlabel('Date/Time')
plt.ylabel('Temp_C')
plt.show()

# %% [markdown]
# ## Anomalies in the data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\LAMECK OMENDA\Downloads\Weather Data.csv')
sns.boxplot(data= df)
plt.show()

# %% [markdown]
# Anomalies were mostly observed in Wind Speed_km/h, Visibility_km, Press_kPa. The reason for this may be because of natural variaton
# or maybe measurement errors.

# %% [markdown]
# # 5. Insights and Conclusions

# %% [markdown]
# In Conclusion Wind Speed_km/h, Visibility_km, Press_kPa have certain anomalies making it difficult to predict the weather
# parameters, whereas Temp_C, Dew Point Temp_C and Rel Hum_% are quite easy to study their behaviour and predict the weather

# %% [markdown]
# These insights gained from the EDA can be useful to farmers for agricultural planning - Helping them know the correct time
# to farm. Also it can be useful to the government for disaster preparedness hence helping them mitigate possible weather conditions.

# %% [markdown]
# # 6. Recommendations for Further Analysis

# %% [markdown]
# Additional data that could have been useful to explore could have been the amount of rainfall recieved across the given time
